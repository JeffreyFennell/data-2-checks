# %% [markdown]
# <a href="https://colab.research.google.com/github/JeffreyFennell/data_1_checks/blob/main/Data_C2_KC_1_Sept22_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Knowledge Check 1
#
# Welcome to your first knowledge check! There will be two more of these per class to test your knowledge of the course up to this point. In addition, this our first attempt at something like this, so please share feedback with your mentors and Code Louisville staff so we can improve it for next class.
#
# This environment is called Google CoLab - it works just like a Jupyter Notebook (which you'll learn more about) but it's hosted by Google so it's a little easier to share with you. However, we still want you to use local Python files so you understand how to get those to GitHub rather than relying on CoLab.

# %% [markdown]
# ## First Assignment
#
# For this assignment, we're going to work with Pandas to explore a little more of the data manipulation and computation side of things.

# %% [markdown]
# ## Your Instructions:
#
# To complete the first knowledge check, do the following:
#
# 1. Create a GitHub repo called "data_1_checks". You will upload ALL knowledge checks to this repo in the future.
# 2. Send that link to your mentor so they can check it when you finish the assignment.
# 3. Make a .py (or .ipynb) file that contains the following (your choice of editor does not matter!) and do the following:
# - Pull in data from an API. Here's a list of public APIs that don't require Auth keys, though if you have another API you want to use feel free: https://apipheny.io/free-api/
# - Find and print TWO descriptive statistics about your data. This can be absolutely anything, from the mean() or sum() of a column to the number of different categories, to the number of null values in a column. We just want to see two pieces of information.
# - Write a query in Pandas to select a particular set of your data. You can use a mask or with .query(), but we want you to pull out a subset based on any parameter you like. This could be "show me every row where HTTPS=False" or anything else.
# - Select and print the SECOND AND THIRD columns of your data frame.
# - Select and print the FIRST 4 rows of you data frame.
# 4. Commit your changes.
# 5. Push your changes to your repo and notify your mentor!
#
#
# ---
#
# This project will test your knowledge of pulling in data from an API then doing some quick manipulation and calculation using pandas.

# %%
import requests
import pandas as pd

# %% [markdown]
# I will be the first to admit I'm not an expert at working with APIs, so I had to fiddle with this to get it to work. However, most APIs will return a JSON object, so I had to pull the 'entries' field from that then feed that into the DataFrame. Sometimes you can just use pd.read_json() but that didn't work in this case.

# %%
r = requests.get('https://api.publicapis.org/entries')
data = r.json()['entries']
df = pd.DataFrame(data=data)
df.head()
# Out:
#          API                                Description    Auth  HTTPS Cors  \
# 0  AdoptAPet          Resource to help get pets adopted  apiKey   True  yes
# 1    Axolotl   Collection of axolotl pictures and facts           True   no
# 2  Cat Facts                            Daily cat facts           True   no
# 3     Cataas  Cat as a service (cats pictures and gifs)           True   no
# 4       Cats               Pictures of cats from Tumblr  apiKey   True   no
#
#                                                 Link Category
# 0  https://www.adoptapet.com/public/apis/pet_list...  Animals
# 1                 https://theaxolotlapi.netlify.app/  Animals
# 2         https://alexwohlbruck.github.io/cat-facts/  Animals
# 3                                https://cataas.com/  Animals
# 4                        https://docs.thecatapi.com/  Animals

# %% [markdown]
# The ```df.describe()``` function can be handy to get a quick view at what your dataset looks like. This is text data, but it will calculate basic descriptive statistics if you have numeric data. It looks like the "top" API from this dataset is SWAPI, which is the Star Wars API. If you're validating your data for unique values, you might look at the **count** and **unique** values under ```Link``` which appears to tell us that all of the links are unique and appear once.

# %%
df.describe()
# Out:
#             API Description  Auth HTTPS     Cors  \
# count      1425        1425  1425  1425     1425
# unique     1412        1371     5     2        4
# top     Numbers       Music        True  unknown
# freq          2           9   669  1333      915
#
#                                                      Link     Category
# count                                                1425         1425
# unique                                               1425           51
# top     https://www.adoptapet.com/public/apis/pet_list...  Development
# freq                                                    1          120

# %% [markdown]
# Here, ```df.shape``` tells us the number of rows and the number of columns. We already have two descriptive pieces of data about our data set, see how easy that is?

# %%
df.shape
# Out:
# (1425, 7)

# %% [markdown]
# Here's a basic way to select things from a dataframe. To be honest, this is the only way I can reliably remember how to do this, which is by using what's called a mask. You can read more [here](https://jakevdp.github.io/PythonDataScienceHandbook/02.06-boolean-arrays-and-masks.html) if you want, or you can use ```df.query()```. Below, I just want to see everything in the DataFrame that has the category "Email".
#
# If you know SQL, this is how you would write the equivalent SQL statement. If not, it will come up later in the course. The SQL syntax is easier to remember for me, but either option works!
#
# ```
# SELECT *
# FROM df
# WHERE Category = 'Email'
# ```

# %%
df[df['Category'] == 'Email']
# Out:
#                            API  \
# 435  Abstract Email Validation
# 436      apilayer mailboxlayer
# 437      Cloudmersive Validate
# 438                     Disify
# 439                   DropMail
# 440                        EVA
# 441             Guerrilla Mail
# 442                   ImprovMX
# 443                    Kickbox
# 444                    mail.gw
# 445                    mail.tm
# 446           MailboxValidator
# 447               MailCheck.ai
# 448                   Mailtrap
# 449                   Sendgrid
# 450                 Sendinblue
# 451                   Verifier
#
#                                            Description    Auth  HTTPS  \
# 435  Validate email addresses for deliverability an...  apiKey   True
# 436                           Email address validation  apiKey   True
# 437  Validate email addresses, phone numbers, VAT n...  apiKey   True
# 438  Validate and detect disposable and temporary e...           True
# 439  GraphQL API for creating and managing ephemera...           True
# 440                           Validate email addresses           True
# 441               Disposable temporary Email addresses           True
# 442              API for free email forwarding service  apiKey   True
# 443                             Email verification API           True
# 444                                     10 Minute Mail           True
# 445                            Temporary Email Service           True
# 446   Validate email address to improve deliverability  apiKey   True
# 447  Prevent users to sign up with temporary email ...           True
# 448  A service for the safe testing of emails sent ...  apiKey   True
# 449  A cloud-based SMTP provider that allows you to...  apiKey   True
# 450  A service that provides solutions relating to ...  apiKey   True
# 451                Verifies that a given email is real  apiKey   True
#
#         Cors                                               Link Category
# 435      yes  https://www.abstractapi.com/email-verification...    Email
# 436  unknown                           https://mailboxlayer.com    Email
# 437      yes              https://cloudmersive.com/validate-api    Email
# 438      yes                            https://www.disify.com/    Email
# 439  unknown                 https://dropmail.me/api/#live-demo    Email
# 440      yes                          https://eva.pingutil.com/    Email
# 441  unknown  https://www.guerrillamail.com/GuerrillaMailAPI...    Email
# 442  unknown                           https://improvmx.com/api    Email
# 443      yes                          https://open.kickbox.com/    Email
# 444      yes                               https://docs.mail.gw    Email
# 445      yes                               https://docs.mail.tm    Email
# 446  unknown    https://www.mailboxvalidator.com/api-email-free    Email
# 447  unknown            https://www.mailcheck.ai/#documentation    Email
# 448  unknown                  https://mailtrap.docs.apiary.io/#    Email
# 449  unknown           https://docs.sendgrid.com/api-reference/    Email
# 450  unknown             https://developers.sendinblue.com/docs    Email
# 451      yes             https://verifier.meetchopra.com/docs#/    Email

# %% [markdown]
# There are more ways to select and subselect data in Pandas than I could write about here. I just want you to attempt to pull a few random columns and a few rows.

# %%
df[['Description','Auth']].head()
# Out:
#                                  Description    Auth
# 0          Resource to help get pets adopted  apiKey
# 1   Collection of axolotl pictures and facts
# 2                            Daily cat facts
# 3  Cat as a service (cats pictures and gifs)
# 4               Pictures of cats from Tumblr  apiKey

# %%
df.iloc[4:10]
# Out:
#          API                                        Description    Auth  \
# 4       Cats                       Pictures of cats from Tumblr  apiKey
# 5  Dog Facts                                   Random dog facts
# 6  Dog Facts                               Random facts of Dogs
# 7       Dogs                 Based on the Stanford Dogs Dataset
# 8      eBird  Retrieve recent or notable birding observation...  apiKey
# 9  FishWatch  Information and pictures about individual fish...
#
#    HTTPS Cors                                               Link Category
# 4   True   no                        https://docs.thecatapi.com/  Animals
# 5   True  yes           https://dukengn.github.io/Dog-facts-API/  Animals
# 6   True  yes                 https://kinduff.github.io/dog-api/  Animals
# 7   True  yes                           https://dog.ceo/dog-api/  Animals
# 8   True   no  https://documenter.getpostman.com/view/664302/...  Animals
# 9   True  yes               https://www.fishwatch.gov/developers  Animals
