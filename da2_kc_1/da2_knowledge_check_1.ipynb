# %%
import requests
import pandas as pd

# %% [markdown]
# ## Reference site for API
#
# #### https://restcountries.com/

# %%
# pull in the api data using the requests module and assign it to 'r'
r = requests.get("https://restcountries.com/v3.1/all")

# determine the type of data I have.
r.headers['content-type']
# Out:
# 'application/json'

# %%
# Create variable by refencing key you want to create df from.
raw_data = r.json()

# %%
# Create df using newly created variable
df= pd.DataFrame(data=raw_data)

# %%
# How many rows and columns are we working with
df.shape
# Out:
# (250, 35)

# %%
# Let's take a look at the data we're working with.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 35 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          250 non-null    object
#  1   tld           249 non-null    object
#  2   cca2          250 non-null    object
#  3   ccn3          249 non-null    object
#  4   cca3          250 non-null    object
#  5   cioc          206 non-null    object
#  6   independent   249 non-null    object
#  7   status        250 non-null    object
#  8   unMember      250 non-null    bool
#  9   currencies    247 non-null    object
#  10  idd           250 non-null    object
#  11  capital       246 non-null    object
#  12  altSpellings  250 non-null    object
#  13  region        250 non-null    object
#  14  subregion     245 non-null    object
#  15  languages     249 non-null    object
#  16  translations  250 non-null    object
#  17  latlng        250 non-null    object
#  18  landlocked    250 non-null    bool
#  19  borders       165 non-null    object
#  20  area          250 non-null    float64
#  21  demonyms      249 non-null    object
#  22  flag          250 non-null    object
#  23  maps          250 non-null    object
#  24  population    250 non-null    int64
#  25  gini          167 non-null    object
#  26  fifa          206 non-null    object
#  27  car           250 non-null    object
#  28  timezones     250 non-null    object
#  29  continents    250 non-null    object
#  30  flags         250 non-null    object
#  31  coatOfArms    250 non-null    object
#  32  startOfWeek   250 non-null    object
#  33  capitalInfo   250 non-null    object
#  34  postalCode    149 non-null    object
# dtypes: bool(2), float64(1), int64(1), object(31)
# memory usage: 65.1+ KB

# %%
# Let's see all of the columns that are present.
df.columns
# Out:
# Index(['name', 'tld', 'cca2', 'ccn3', 'cca3', 'cioc', 'independent', 'status',
#        'unMember', 'currencies', 'idd', 'capital', 'altSpellings', 'region',
#        'subregion', 'languages', 'translations', 'latlng', 'landlocked',
#        'borders', 'area', 'demonyms', 'flag', 'maps', 'population', 'gini',
#        'fifa', 'car', 'timezones', 'continents', 'flags', 'coatOfArms',
#        'startOfWeek', 'capitalInfo', 'postalCode'],
#       dtype='object')

# %%
# Let's drop some of the unnecessary columns.
df = df.drop(columns= ['tld', 'cca2', 'ccn3', 'cca3', 'cioc','flag', 'maps', 'gini', 'fifa','flags', 'coatOfArms','currencies', 'idd','altSpellings', 'region', 'subregion','translations', 'latlng','demonyms', 'flag','maps'])

# %%
# Check our results.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         250 non-null    object
#  1   independent  249 non-null    object
#  2   status       250 non-null    object
#  3   unMember     250 non-null    bool
#  4   capital      246 non-null    object
#  5   languages    249 non-null    object
#  6   landlocked   250 non-null    bool
#  7   borders      165 non-null    object
#  8   area         250 non-null    float64
#  9   population   250 non-null    int64
#  10  car          250 non-null    object
#  11  timezones    250 non-null    object
#  12  continents   250 non-null    object
#  13  startOfWeek  250 non-null    object
#  14  capitalInfo  250 non-null    object
#  15  postalCode   149 non-null    object
# dtypes: bool(2), float64(1), int64(1), object(12)
# memory usage: 28.0+ KB

# %%
# Which countries are members of the United Nations?
member = df[df['unMember'] == True]
member
# Out:
#                                                   name independent  \
# 0    {'common': 'Jordan', 'official': 'Hashemite Ki...        True
# 2    {'common': 'Serbia', 'official': 'Republic of ...        True
# 3    {'common': 'Andorra', 'official': 'Principalit...        True
# 7    {'common': 'Bolivia', 'official': 'Plurination...        True
# 8    {'common': 'Libya', 'official': 'State of Liby...        True
# ..                                                 ...         ...
# 242  {'common': 'Switzerland', 'official': 'Swiss C...        True
# 245  {'common': 'Sudan', 'official': 'Republic of t...        True
# 246  {'common': 'Tajikistan', 'official': 'Republic...        True
# 247  {'common': 'Uruguay', 'official': 'Oriental Re...        True
# 248  {'common': 'Cyprus', 'official': 'Republic of ...        True
#
#                   status  unMember             capital  \
# 0    officially-assigned      True             [Amman]
# 2    officially-assigned      True          [Belgrade]
# 3    officially-assigned      True  [Andorra la Vella]
# 7    officially-assigned      True             [Sucre]
# 8    officially-assigned      True           [Tripoli]
# ..                   ...       ...                 ...
# 242  officially-assigned      True              [Bern]
# 245  officially-assigned      True          [Khartoum]
# 246  officially-assigned      True          [Dushanbe]
# 247  officially-assigned      True        [Montevideo]
# 248  officially-assigned      True           [Nicosia]
#
#                                              languages  landlocked  \
# 0                                    {'ara': 'Arabic'}       False
# 2                                   {'srp': 'Serbian'}        True
# 3                                   {'cat': 'Catalan'}        True
# 7    {'aym': 'Aymara', 'grn': 'Guaraní', 'que': 'Qu...        True
# 8                                    {'ara': 'Arabic'}       False
# ..                                                 ...         ...
# 242  {'fra': 'French', 'gsw': 'Swiss German', 'ita'...        True
# 245                {'ara': 'Arabic', 'eng': 'English'}       False
# 246                 {'rus': 'Russian', 'tgk': 'Tajik'}        True
# 247                                 {'spa': 'Spanish'}       False
# 248                 {'ell': 'Greek', 'tur': 'Turkish'}       False
#
#                                       borders       area  population  \
# 0                   [IRQ, ISR, PSE, SAU, SYR]    89342.0    10203140
# 2    [BIH, BGR, HRV, HUN, UNK, MKD, MNE, ROU]    88361.0     6908224
# 3                                  [FRA, ESP]      468.0       77265
# 7                   [ARG, BRA, CHL, PRY, PER]  1098581.0    11673029
# 8              [DZA, TCD, EGY, NER, SDN, TUN]  1759540.0     6871287
# ..                                        ...        ...         ...
# 242                 [AUT, FRA, ITA, LIE, DEU]    41284.0     8654622
# 245       [CAF, TCD, EGY, ERI, ETH, LBY, SSD]  1886068.0    43849269
# 246                      [AFG, CHN, KGZ, UZB]   143100.0     9537642
# 247                                [ARG, BRA]   181034.0     3473727
# 248                                       NaN     9251.0     1207361
#
#                                      car    timezones       continents  \
# 0    {'signs': ['HKJ'], 'side': 'right'}  [UTC+03:00]           [Asia]
# 2    {'signs': ['SRB'], 'side': 'right'}  [UTC+01:00]         [Europe]
# 3    {'signs': ['AND'], 'side': 'right'}  [UTC+01:00]         [Europe]
# 7    {'signs': ['BOL'], 'side': 'right'}  [UTC-04:00]  [South America]
# 8    {'signs': ['LAR'], 'side': 'right'}  [UTC+01:00]         [Africa]
# ..                                   ...          ...              ...
# 242   {'signs': ['CH'], 'side': 'right'}  [UTC+01:00]         [Europe]
# 245  {'signs': ['SUD'], 'side': 'right'}  [UTC+03:00]         [Africa]
# 246   {'signs': ['TJ'], 'side': 'right'}  [UTC+05:00]           [Asia]
# 247  {'signs': ['ROU'], 'side': 'right'}  [UTC-03:00]  [South America]
# 248    {'signs': ['CY'], 'side': 'left'}  [UTC+02:00]         [Europe]
#
#     startOfWeek                   capitalInfo  \
# 0        sunday    {'latlng': [31.95, 35.93]}
# 2        monday     {'latlng': [44.83, 20.5]}
# 3        monday      {'latlng': [42.5, 1.52]}
# 7        monday  {'latlng': [-19.02, -65.26]}
# 8        sunday    {'latlng': [32.88, 13.17]}
# ..          ...                           ...
# 242      monday     {'latlng': [46.92, 7.47]}
# 245      monday     {'latlng': [15.6, 32.53]}
# 246      monday    {'latlng': [38.55, 68.77]}
# 247      monday  {'latlng': [-34.85, -56.17]}
# 248      monday    {'latlng': [35.17, 33.37]}
#
#                                            postalCode
# 0           {'format': '#####', 'regex': '^(\d{5})$'}
# 2          {'format': '######', 'regex': '^(\d{6})$'}
# 3    {'format': 'AD###', 'regex': '^(?:AD)*(\d{3})$'}
# 7                                                 NaN
# 8                                                 NaN
# ..                                                ...
# 242          {'format': '####', 'regex': '^(\d{4})$'}
# 245         {'format': '#####', 'regex': '^(\d{5})$'}
# 246        {'format': '######', 'regex': '^(\d{6})$'}
# 247         {'format': '#####', 'regex': '^(\d{5})$'}
# 248          {'format': '####', 'regex': '^(\d{4})$'}
#
# [193 rows x 16 columns]

# %%
# How many countries are UN members?
member['unMember'].count()
# Out:
# 193

# %%
# What's the mean population of countries that are members of the UN?
member['population'].mean()
# Out:
# 40050066.35233161

# %%
# What's the largest country, by population, that's a member of the UN?
member[member['population'] == member['population'].max()]
# Out:
#                                                  name independent  \
# 49  {'common': 'China', 'official': 'People's Repu...        True
#
#                  status  unMember    capital           languages  landlocked  \
# 49  officially-assigned      True  [Beijing]  {'zho': 'Chinese'}       False
#
#                                               borders       area  population  \
# 49  [AFG, BTN, MMR, HKG, IND, KAZ, NPL, PRK, KGZ, ...  9706961.0  1402112000
#
#                                    car    timezones continents startOfWeek  \
# 49  {'signs': ['RC'], 'side': 'right'}  [UTC+08:00]     [Asia]      monday
#
#                     capitalInfo                                  postalCode
# 49  {'latlng': [39.92, 116.38]}  {'format': '######', 'regex': '^(\d{6})$'}

# %%
# Which UN member has the smallest population?
member[member['population'] == member['population'].min()]
# Out:
#                                                  name independent  \
# 39  {'common': 'Vatican City', 'official': 'Vatica...        True
#
#                  status  unMember         capital  \
# 39  officially-assigned      True  [Vatican City]
#
#                              languages  landlocked borders  area  population  \
# 39  {'ita': 'Italian', 'lat': 'Latin'}        True   [ITA]  0.44         451
#
#                                   car    timezones continents startOfWeek  \
# 39  {'signs': ['V'], 'side': 'right'}  [UTC+01:00]   [Europe]      monday
#
#                   capitalInfo postalCode
# 39  {'latlng': [41.9, 12.45]}        NaN

# %%
# Print only 2nd and 3rd columns
only_2_cols = df.iloc[:, 1:3]
only_2_cols.head(5)
# Out:
#   independent               status
# 0        True  officially-assigned
# 1       False  officially-assigned
# 2        True  officially-assigned
# 3        True  officially-assigned
# 4       False  officially-assigned

# %%
# Print first 4 rows
only_4_rows = df.iloc[:4]
only_4_rows.head(5)
# Out:
#                                                 name independent  \
# 0  {'common': 'Jordan', 'official': 'Hashemite Ki...        True
# 1  {'common': 'Northern Mariana Islands', 'offici...       False
# 2  {'common': 'Serbia', 'official': 'Republic of ...        True
# 3  {'common': 'Andorra', 'official': 'Principalit...        True
#
#                 status  unMember             capital  \
# 0  officially-assigned      True             [Amman]
# 1  officially-assigned     False            [Saipan]
# 2  officially-assigned      True          [Belgrade]
# 3  officially-assigned      True  [Andorra la Vella]
#
#                                            languages  landlocked  \
# 0                                  {'ara': 'Arabic'}       False
# 1  {'cal': 'Carolinian', 'cha': 'Chamorro', 'eng'...       False
# 2                                 {'srp': 'Serbian'}        True
# 3                                 {'cat': 'Catalan'}        True
#
#                                     borders     area  population  \
# 0                 [IRQ, ISR, PSE, SAU, SYR]  89342.0    10203140
# 1                                       NaN    464.0       57557
# 2  [BIH, BGR, HRV, HUN, UNK, MKD, MNE, ROU]  88361.0     6908224
# 3                                [FRA, ESP]    468.0       77265
#
#                                    car    timezones continents startOfWeek  \
# 0  {'signs': ['HKJ'], 'side': 'right'}  [UTC+03:00]     [Asia]      sunday
# 1  {'signs': ['USA'], 'side': 'right'}  [UTC+10:00]  [Oceania]      monday
# 2  {'signs': ['SRB'], 'side': 'right'}  [UTC+01:00]   [Europe]      monday
# 3  {'signs': ['AND'], 'side': 'right'}  [UTC+01:00]   [Europe]      monday
#
#                   capitalInfo  \
# 0  {'latlng': [31.95, 35.93]}
# 1  {'latlng': [15.2, 145.75]}
# 2   {'latlng': [44.83, 20.5]}
# 3    {'latlng': [42.5, 1.52]}
#
#                                          postalCode
# 0         {'format': '#####', 'regex': '^(\d{5})$'}
# 1                                               NaN
# 2        {'format': '######', 'regex': '^(\d{6})$'}
# 3  {'format': 'AD###', 'regex': '^(?:AD)*(\d{3})$'}
